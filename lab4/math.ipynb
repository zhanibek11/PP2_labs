# %%
#1
import math
a = int(input())
print(math.radians(a))
# Out:
# 0.2617993877991494

# %%
#2
import math
height = 5
base1 = 6
base2 = 5
print(0.5*(base1+base2)*height)

#i dont really understand how to use math library here , sorry agai )
# Out:
# 27.5

# %%
#3
numsides = int(input("Number of sides: "))
length = int(input("Length of a side: "))

print("The area of the polygon is: ", (numsides * (length ** 2)) // (4* math.tan(math.pi/numsides)) )
# Out:
# The area of the polygon is:  625.0

# %%
#4
lengthb = int(input("Length of base: "))
heightp = int(input("Height of parallelogram: "))
print(lengthb * heightp)
# Out:
# 30
