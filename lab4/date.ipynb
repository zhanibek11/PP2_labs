# %%
#1
from datetime import datetime, timedelta
print(datetime.now() - timedelta(5))
# Out:
# 2025-02-16 20:16:30.518418

# %%
#2
from datetime import datetime, timedelta
print("yesterday: ",datetime.now()-timedelta(1))
print("today: ",datetime.now())
print("tomorrow: ",datetime.now()+timedelta(1))
# Out:
# yesterday:  2025-02-20 20:16:28.446615
# today:  2025-02-21 20:16:28.446652
# tomorrow:  2025-02-22 20:16:28.446672

# %%
#3
import datetime
print(datetime.datetime.now().strftime("%Y-%m-%d %M:%S"))
# Out:
# 2025-02-21 16:55

# %%
#4
import datetime
time1= input("Write first date:")
time2 = input("Write second date: ")
format = "%Y-%m-%d %H:%M:%S"
ans1= datetime.datetime.strptime(time1, format)
ans2 =datetime.datetime.strptime(time2, format)
print("Difference in seconds:",abs(ans1-ans2).total_seconds())
# Out:
# Difference in seconds: 2310.0
