# %%
#1
import os 

path = "/Users/kuanyshev11/Documents/zhanibek/labs"

print([d for d in os.listdir(path) if os.path.isdir(d)])
print([f for f in os.listdir() if os.path.isfile(f)])
print(os.listdir())
# Out:
# []
# ['builtinfunctions.ipynb', 'directory.ipynb']
# ['builtinfunctions.ipynb', 'directory.ipynb']

# %%
#2
import os

path = "lolo.txt"

print(os.access(path,os.F_OK))
print(os.access(path,os.R_OK))
print(os.access(path,os.W_OK))
print(os.access(path,os.X_OK))
# Out:
# True
# True
# True
# False

# %%
#3
import os

path = "/Users/kuanyshev11/Documents/zhanibek/labs/lab6/lolo.txt"

if os.path.exists(path):
    print("folder: ", os.path.dirname(path))
    print("name: ", os.path.basename(path))
# Out:
# folder:  /Users/kuanyshev11/Documents/zhanibek/labs/lab6
# name:  lolo.txt

# %%
#4
with open("lolo.txt", mode = "r") as file:
    print(len(file.readlines()))
# Out:
# 1

# %%
#5
list = ["Aktau", "Is a", "Dream"]

with open("lolo.txt" , mode = "w") as file:
    for x in list:
        file.write(x + " ")
    file.close()

    #everything works!!!!!!!!

# %%
#6
import string

for letter in string.ascii_uppercase:
    a = letter + ".txt"
    with open( a , mode = "w") as file:
        file.write("")

# %%
#7
import os
s = "/Users/kuanyshev11/Documents/zhanibek/labs/lab6/lolo.txt"
a = "/Users/kuanyshev11/Documents/zhanibek/labs/lab6/A.txt"
os.system("cp " + s + " " + a)
# Out:
# 0

# %%
#8
import os
if os.path.exists("todelete.txt"):
    os.remove("todelete.txt")
else:
    print("No file")
