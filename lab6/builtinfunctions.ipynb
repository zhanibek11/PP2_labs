# %%
#1
import math
def k(list):
    return math.prod(list)
list = [1,2,3,4]
print(k(list))
# Out:
# 24

# %%
#2

def k(lol):
    colvo1 = 0
    colvo2 = 0
    for x in lol:
        if islower(x):
            colvo1 = colvo1 + 1
        elif isupper(x):
            colvo2 = colvo2 + 1
    print("low: ", colvo1)
    print("up: ", colvo2)

lol = "gggAA"

k(lol)
# Out:
# low:  3
# up:  2

# %%
#3
def palindromee(k):
    a = ''.join(reversed(k))
    return a == k
k = "kaak"
l = "notpalindrome"
print(palindromee(k))
print(palindromee(l))
# Out:
# True
# False

# %%
#4
import math
import time

def k11(a,b):
    time.sleep(b / 1000)
    k = math.sqrt(a)
    print("Square root of ",a,"after",b,"milliseconds is ", k)

a = 25100
b = 2123

k11(a,b)
# Out:
# Square root of  25100 after 2123 milliseconds is  158.42979517754858

# %%
#5
def k(turtle):
    return all(turtle)
turtle = ("Im", "The best" , "For Real")
p = (0,11,"lokoko")
print(k(turtle))
print(k(p))
# Out:
# True
# False
